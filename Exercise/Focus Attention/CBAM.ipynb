# %% [markdown]
# <h1 align=center><font size = 5>CBAM</h1 >

# %% [markdown]
# <h3>Objective for this Notebook</h3>
# <h5> 1. 觀看架構圖，試著撰寫出模型</h5>
# <hr>

# %% [markdown]
# ![CBAM.png](attachment:CBAM.png)

# %%
import torch
import torch.nn as nn

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class ChannelAttention(nn.Module):
    def __init__(self, in_channels, reduction_ratio=16):
        super(ChannelAttention, self).__init__()


        self.mlp = nn.Sequential(
            nn.Flatten(),  # [B, C, 1, 1] -> [B, C]
            #linear
            nn.ReLU(),
            #linear
        )

    def forward(self, x):
        #answer



        scale = torch.sigmoid(out).view(x.size(0), x.size(1), 1, 1)
        return x * scale


class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=7):
        super(SpatialAttention, self).__init__()
        #padding=kernel_size // 2

    def forward(self, x):
        #torch.max
        #torch.mean
        # torch.cat [B, 2, H, W]
        # scale=torch.sigmoid [B, 1, H, W]
        return x * scale


class CBAM(nn.Module):
    def __init__(self, channels):
        super(CBAM, self).__init__()




    def forward(self, x):




        return x

# %% [markdown]
# # 雙擊展開正確答案
#
# <!--
#
# class ChannelAttention(nn.Module):
#     def __init__(self, in_channels, reduction_ratio=16):
#         super(ChannelAttention, self).__init__()
#         self.avg_pool = nn.AdaptiveAvgPool2d(1)
#         self.max_pool = nn.AdaptiveMaxPool2d(1)
#
#
#         self.mlp = nn.Sequential(
#             nn.Flatten(),  # [B, C, 1, 1] -> [B, C]
#             nn.Linear(in_channels, in_channels // reduction_ratio),
#             nn.ReLU(),
#             nn.Linear(in_channels // reduction_ratio, in_channels)
#         )
#
#     def forward(self, x):
#         avg_out = self.mlp(self.avg_pool(x))
#         max_out = self.mlp(self.max_pool(x))
#         out = avg_out + max_out
#         scale = torch.sigmoid(out).view(x.size(0), x.size(1), 1, 1)
#         return x * scale
#
#
#
# class SpatialAttention(nn.Module):
#     def __init__(self, kernel_size=7):
#         super(SpatialAttention, self).__init__()
#         self.conv = nn.Conv2d(2, 1, kernel_size, padding=kernel_size // 2)
#
#     def forward(self, x):
#         max_out, _ = torch.max(x, dim=1, keepdim=True)
#         avg_out = torch.mean(x, dim=1, keepdim=True)
#         concat = torch.cat([max_out, avg_out], dim=1)  # [B, 2, H, W]
#         scale = torch.sigmoid(self.conv(concat))       # [B, 1, H, W]
#         return x * scale
#
#
#
# class CBAM(nn.Module):
#     def __init__(self, channels):
#         super(CBAM, self).__init__()
#         self.channel_attention = ChannelAttention(channels)
#         self.spatial_attention = SpatialAttention()
#
#     def forward(self, x):
#         x = self.channel_attention(x)
#         x = self.spatial_attention(x)
#         return x
#
# -->
